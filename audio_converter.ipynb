# %%
from pydub import AudioSegment
import numpy as np
import matplotlib.pyplot as plt

# %%
audio = AudioSegment.from_file('./286946560/audio.mp3')
audio = audio[:60*1000]

# %%
faded = audio.fade(to_gain=-100, start=53000, end=59500)
faded.export('./286946560/audio_cut.mp3', format='mp3')
# Out:
# <_io.BufferedRandom name='./286946560/audio_cut.mp3'>

# %%
faded
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
